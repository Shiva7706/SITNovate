# %%
import pandas as pd
data = pd.read_csv("Data/new_data.csv")

# %%
Q1 = data["Production"].quantile(0.25)
Q3 = data["Production"].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
data[data["Production"]>IQR]
# Out:
#        Unnamed: 0  Crop  Season   State  Production  Annual_Rainfall  \
# 115           115  Rice  Winter   Assam     1647296           2051.4
# 116           116  Rice  Winter   Assam     1647296           2051.4
# 117           117  Rice  Winter   Assam     1647296           2051.4
# 118           118  Rice  Winter   Assam     1647296           2051.4
# 119           119  Rice  Winter   Assam     1647296           2051.4
# ...           ...   ...     ...     ...         ...              ...
# 95196       95196  Rice  Winter  Odisha     6280410           1635.9
# 95197       95197  Rice  Winter  Odisha     6280410           1635.9
# 95198       95198  Rice  Winter  Odisha     6280410           1635.9
# 95199       95199  Rice  Winter  Odisha     6280410           1635.9
# 95200       95200  Rice  Winter  Odisha     6280410           1635.9
#
#              Soil Type Pesticide Usage       pH Temperature Fertilizer Usage
# ...

# %%
import seaborn as sns
